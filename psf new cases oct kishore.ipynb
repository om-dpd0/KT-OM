# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
port = pd.read_csv('PORTFOLIO_CNSSS29BABF004UI6MPG.csv')
file = pd.read_excel('DPD SMS (4) copy.xlsx')
# Out:
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_65842/3165338040.py:1: DtypeWarning: Columns (22,23,80,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   port = pd.read_csv('PORTFOLIO_CNSSS29BABF004UI6MPG.csv')

# %%
file = file.loc[file['Company']=='PDMSAI']
print(len(file), len(port))
file.head()
# Out:
# 15133 25839
#         Due List ECS/NON ECS    Division Company            Branch  \
# 2353  Before May     Non ECS  Collection  PDMSAI    Chintal (Auto)
# 2354  Before May     Non ECS  Collection  PDMSAI           Amangal
# 2355  Before May     Non ECS  Collection  PDMSAI  Nizamabad (Auto)
# 2356  Before May     Non ECS  Collection  PDMSAI    Chintal (Auto)
# 2357  Before May     Non ECS  Collection  PDMSAI    Chintal (Auto)
#
#            Centre Name        Loan Number  PAID  Vehicle No Agreement Date  \
# 2353    Chintal (Auto)  L3WRTSCHL-1712001   NaN   TS34T0361     2016-09-23
# 2354       Amangal(2W)          ARKLKY-02   NaN  TS06UB6534     2016-10-14
# 2355  Nizamabad (Auto)           ANZBS-23   NaN  TS16UB1887     2017-01-12
# 2356    Chintal (Auto)          ARMSPT-03   NaN   TS34T2169     2017-02-23
# 2357    Chintal (Auto)           ACHTL-64   NaN   TS34T1316     2017-03-03
#
#           Customer Name  Cust Mobile              Guarantor  Guar Mobile  \
# ...

# %%
file.loc[file['Inst. Date']>='2024-03-01']['ECS/NON ECS'].value_counts()
# Out:
# ECS/NON ECS
# Non ECS    12112
# ECS          684
# Name: count, dtype: int64

# %%
file.loc[~file['Loan Number'].isin(port['Loan Number']) & (file['Inst. Date']>='2024-03-01')]['Inst. Date'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
new_alloc = file.loc[(~(file['Loan Number'].isin(port['Loan Number']))) & (file['Inst. Date']>='2024-03-01')]

# %%
new_alloc
# Out:
# Empty DataFrame
# Columns: [Due List, ECS/NON ECS, Division, Company, Branch, Centre Name, Loan Number, PAID, Vehicle No, Agreement Date, Customer Name, Cust Mobile, Guarantor, Guar Mobile, Vehicle Type, Class, First Due Date, Last Due Date, Inst. Date, Month TBC, Total Dues, LPC Dues, VAS/HL, EMI Due, EMI Due 2, Running EMI, Paid EMIs, Balance EMIs, INST, Last Rcvd Date, Seize Date, Customer Address, Collection Executive, Source Name, Lead Owner]
# Index: []

# %%
len(file.loc[(~(file['Loan Number'].isin(port['Loan Number'])))& (file['Inst. Date']>='2024-03-01')])
# Out:
# 0

# %%
len(file)
# Out:
# 15133

# %%
port.loc[port['Loan Number'].isin(file['Loan Number'])]
# Out:
#                          Name          Loan Number  Amount Pending  \
# 1               MADIGA  GOPAL  L2WNAPANP-210101043         4985.00
# 2                N  THIPPANNA  L2WNAPANP-210801825         5290.00
# 3           MALA  ARUN PRASAD  L2WNAPANP-210801854         4670.36
# 5         MOOD  NAGENDRA NAIK  L2WNAPANP-210901911         4310.36
# 6                S S   APARNA  L2WNAPANP-211001971         4780.00
# ...                       ...                  ...             ...
# 25833         PANGA  SRIKANTH  L3WUTSWNG-230500365         5550.00
# 25834  THALAKALAPALLY  SURESH  L3WUTSWNG-230800367         6170.00
# 25836  GANJARABOINA  VENGAIAH  L4WNAPPKM-230802797         5150.00
# 25837   MOHAMMAD  KHAJA PASHA  L4WRTSKKT-221200468         7761.00
# 25838         DARSHANAM  RAJU  L4WUTSMLL-230500680        13600.00
#
#          Due Date   Status  State      Mobile  Principal  Tenure  \
# 1      2024-03-25  PENDING    NaN  8790533340        NaN      24
# ...

# %%
new_alloc.head()
# Out:
# Empty DataFrame
# Columns: [Due List, ECS/NON ECS, Division, Company, Branch, Centre Name, Loan Number, PAID, Vehicle No, Agreement Date, Customer Name, Cust Mobile, Guarantor, Guar Mobile, Vehicle Type, Class, First Due Date, Last Due Date, Inst. Date, Month TBC, Total Dues, LPC Dues, VAS/HL, EMI Due, EMI Due 2, Running EMI, Paid EMIs, Balance EMIs, INST, Last Rcvd Date, Seize Date, Customer Address, Collection Executive, Source Name, Lead Owner]
# Index: []

# %%
new_alloc['ECS/NON ECS'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
new_alloc.rename(columns={'Customer Name':'Name','Vehicle No':'Vehicle number (Wheeler)','Cust Mobile':'Mobile',
                     'Customer Address':'Address','Guarantor':'Guarantor name','Guar Mobile':'Guarantor Mobile',
                     'Installments':'Tenure', 'Inst. Date':'Due Date','Month TBC':'Amount Pending','Last Rcvd Date':'Last Repayment Date',
                     'Nach Status':'E-Nach Enabled','EMI Due Count':'EMIs Pending','Gross TBC':'Total Dues', "ECS/NON ECS":'E-Nach Enabled', 'INST':'Tenure', 'EMI Due 2':'EMIs Pending'
                    },inplace=True)
# Out:
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_65842/329552961.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_alloc.rename(columns={'Customer Name':'Name','Vehicle No':'Vehicle number (Wheeler)','Cust Mobile':'Mobile',

# %%
new_alloc.drop(['Paid', 'Collection Executive', 'Lead Owner', 'Status',
       'Prev Adv Coll', 'Month TBC Received',
       'Total Dues', 'Month Collected',
       'Gross Demand', 'Gross Collected', 'Coll/Demand (%)', 'Receipt Count',
       'Advance Coll.', 'Running EMI Count', 'Paid EMIs',
       'Balance EMIs', 'LPI Dues',  'Cumm VAS',
       'VAS Collected', 'VAS Due', 'Cumm Handloan', 'Handloan Collected',
       'Handloan Due','Fuel Type', 'Seize Date' ],axis=1, inplace=True, errors='ignore')
# Out:
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_65842/1422604765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_alloc.drop(['Paid', 'Collection Executive', 'Lead Owner', 'Status',

# %%
new_alloc.head()
# Out:
# Empty DataFrame
# Columns: [Due List, E-Nach Enabled, Division, Company, Branch, Centre Name, Loan Number, PAID, Vehicle number (Wheeler), Agreement Date, Name, Mobile, Guarantor name, Guarantor Mobile, Vehicle Type, Class, First Due Date, Last Due Date, Due Date, Amount Pending, LPC Dues, VAS/HL, EMI Due, EMIs Pending, Running EMI, Tenure, Last Repayment Date, Address, Source Name]
# Index: []

# %%
port.head()
# Out:
#                 Name          Loan Number  Amount Pending    Due Date  \
# 0     PITTI  BHASKAR  L2WNAPANP-201100778         4620.00  2024-03-12
# 1      MADIGA  GOPAL  L2WNAPANP-210101043         4985.00  2024-03-25
# 2       N  THIPPANNA  L2WNAPANP-210801825         5290.00  2024-03-15
# 3  MALA  ARUN PRASAD  L2WNAPANP-210801854         4670.36  2024-03-05
# 4      KUMMARA  BABU  L2WNAPANP-210901861         4565.69  2024-03-05
#
#       Status  State      Mobile  Principal  Tenure  Interest Rate  EMI  \
# 0  COLLECTED    NaN  8464844038        0.0      30            0.0  0.0
# 1    PENDING    NaN  8790533340        NaN      24            NaN  NaN
# 2    PENDING    NaN  9652744893        NaN      24            NaN  NaN
# 3    PENDING    NaN  7386704813        NaN      30            NaN  NaN
# 4    PENDING    NaN  9346094933        NaN      30            NaN  NaN
#
#   E-Nach Enabled  Occupation  Gender  City  Pin Code  CIBIL Score  \
# ...

# %%
new_alloc['Original Amount Pending'] = new_alloc['Amount Pending']
# Out:
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_6394/3016062651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_alloc['Original Amount Pending'] = new_alloc['Amount Pending']

# %%
new_alloc['Assigned Date'] = '2024-03-02'
new_alloc['Allocation Start Date'] = new_alloc['Assigned Date']
new_alloc['Allocation Name'] = 'Padmasai Predue-X'
new_alloc['Allocation amount'] = new_alloc['Original Amount Pending']
new_alloc['Allocation ID'] = 'FEBRUARY2024'
new_alloc['Status'] = 'PENDING'
new_alloc['Allocation End Date'] = '2024-03-31'
# Out:
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_6394/2527985816.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_alloc['Assigned Date'] = '2024-03-02'
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_6394/2527985816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_alloc['Allocation Start Date'] = new_alloc['Assigned Date']
# /var/folders/h9/kl6cgyq520qdy0yfhjv5bnjw0000gn/T/ipykernel_6394/2527985816.py:3: SettingWithCopyWarning:
# ...

# %%
new_alloc.loc[new_alloc['E-Nach Enabled']=='ECS', 'E-Nach Enabled'] = 'True'
new_alloc.loc[new_alloc['E-Nach Enabled']!='True', 'E-Nach Enabled'] = 'False'

# %%
new_alloc[['Loan Number', 'Vehicle number (Wheeler)',
       'Branch', 'Agreement Date', 'Name', 'Mobile', 
       'Guarantor name', 'Guarantor Mobile', 'Vehicle Type', 'Class', 'Tenure',
       'Due Date', 'Amount Pending', 'EMIs Pending',
       'Last Repayment Date', 'Assigned Date', 'Allocation ID', 'E-Nach Enabled', 'Status', 'Original Amount Pending', 'Allocation Name', 'Allocation amount',
       'Allocation Start Date', 'Allocation End Date']].to_csv('pdmsai new alloc nach.csv', index=False)

# %%
new_alloc['E-Nach Enabled'].value_counts()
# Out:
# E-Nach Enabled
# True    94
# Name: count, dtype: int64

# %%
new_alloc.loc[new_alloc['E-Nach Enabled']=='True']
# Out:
# Empty DataFrame
# Columns: [Due List, E-Nach Enabled, Division, Company, Branch, Centre Name, Loan Number, PAID, Vehicle number (Wheeler), Agreement Date, Name, Mobile, Guarantor name, Guarantor Mobile, Vehicle Type, Class, First Due Date, Last Due Date, Due Date, Amount Pending, LPC Dues, VAS/HL, EMI Due, EMIs Pending, Running EMI, Tenure, Last Repayment Date, Address, Source Name]
# Index: []

# %%
len(new_alloc)
# Out:
# 160

# %%
print(new_alloc['Allocation Name'].unique())
new_alloc['Due Date'].value_counts()
# Out:
# ['Padmasai Predue-X']
# Due Date
# 2024-02-15    160
# Name: count, dtype: int64

# %%
new_alloc['Status'].value_counts()
# Out:
# Status
# PENDING    160
# Name: count, dtype: int64

# %%
print(len(new_alloc), new_alloc['Original Amount Pending'].sum())
# Out:
# 160 795965.38
